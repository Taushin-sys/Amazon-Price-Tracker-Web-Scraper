# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# Connect to website

URL = "https://www.amazon.com/dp/B0GZ7DWKCS"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

page = requests.get(URL, headers=headers)

print(page.status_code)
print("productTitle" in page.text)
# Out:
# 200
# True

# %%
page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text().strip()

price = price.replace("INR", "").replace(",", "").strip()
#price = soup2.find_all('span', class_='a-offscreen')[2].get_text().strip()

print(title)
print(price)
# Out:
# Funny Tee Shirts Best Data Analyst Ever T-Shirt
# 1771.97

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-06-01

# %%
import csv

header = ['Title', 'Price', 'Date']
data =[title, price, today]

#with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\mkhal\Desktop\AmazonWebScraperDataset.csv")

print(df)
# Out:
#                                              Title    Price        Date
# 0  Funny Tee Shirts Best Data Analyst Ever T-Shirt  1771.97  2026-06-01
# 1  Funny Tee Shirts Best Data Analyst Ever T-Shirt  1771.97  2026-06-01
# 2  Funny Tee Shirts Best Data Analyst Ever T-Shirt  1771.97  2026-06-01
# 3  Funny Tee Shirts Best Data Analyst Ever T-Shirt  1771.97  2026-06-01
# 4  Funny Tee Shirts Best Data Analyst Ever T-Shirt  1771.97  2026-06-01

# %%
# Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = "https://www.amazon.com/dp/B0GZ7DWKCS"

    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

    page = requests.get(URL, headers=headers)
    
    soup1 = BeautifulSoup(page.content, "html.parser")
    
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text().strip()

    #price = price.replace("INR", "").replace(",", "").strip()
    price = soup2.find_all('span', class_='a-offscreen')[2].get_text().strip()
    price = float(price.replace("INR", "").replace(",", "").strip())
    
    import datetime

    today = datetime.date.today()
    
    import csv

    header = ['Title', 'Price', 'Date']

    print(title)
    print(price)
    
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

    if(price < 1700):
        send_mail()

# %%
import time

while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv('AmazonWebScraperDataset.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    # server.starttls()
    server.ehlo()
    server.login('taushin112233@gmail.com', 'xxxxxxxxxxxxxx')

    subject = "The Shirt you want is below INR 1700! Now is your chance to buy!"
    body = "Tosh, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Shirts-Analyst-T-Shirt-X-Large/dp/B0GZ7DWKCS/ref=sr_1_7?crid=2U5JEDPKF9YVM&dib=eyJ2IjoiMSJ9.MPbIaBcVPlxxhGvYEfnRq6EwV7Ki3pH3CbOqLIYDsndclLQ_aLXSFIMo7K4Gv9AwJgRTw4ldEnjRR0-8HmPAtpki6zS4dhcxkKacRl2ker_IVNTkwEQ1DWSp5iA4UJ3Qghad0E8XE4veLLIMgczYWS738bQCqcVD_0PcoQcryjI5DKjh2zrH7X3kz3FpDyrB8GyXi6yR8Dk1j__-VhsZ0Rm5HMbcC5JFlr7fzUY0Jm84SPG_5RVWHFQ5SA3VEM3aObwJMXG3vGgJEnvTGBd5vsRG22iOhxGt2L2Vx-6_KZ0.8AL1xIGXfxCOAY3CQJpgVeOC1LxGABhT2KT8t--ER1s&dib_tag=se&keywords=got%2Bdata%2Btshirt&qid=1780289133&sprefix=got%2Bdata%2Caps%2C392&sr=8-7&th=1&psc=1"

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'taushin112233@gmail.com',
        msg
)
